# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from os import environ

key_index = ['avg_time',
            'max_time', 
            'med_time',
            'min_time',
            'std_dev']

#
# Read report filename from environment varilable 'file' 
#
filename = environ['input_data_fp']
fig_no = int(environ['input_fig_number'])
if fig_no == 1:
    color_list = ['green']
    fig_size = 10
else:
    color_list = ['green', 'orange', 'red', 'blue']
    fig_size = 20
    
with open(filename) as data_file:
    data = json.load(data_file)
    d = pd.DataFrame(data)  

# drop empty 'time_list'
for c in d:
    if (d[c]['time_list'] == []) :
        d.drop(c, axis=1, inplace=True)
    
# Select columns and rows
d.loc[key_index, :]
# Out:
#          test_chrome_gmail_ail_reply_mail test_firefox_gmail_ail_reply_mail
# avg_time                          121.852                           253.704
# max_time                          155.556                           444.444
# med_time                          122.222                           244.444
# min_time                              100                           211.111
# std_dev                           12.6632                           40.1728

# %%
# Retrive 'run_time' from each run
runtime = pd.DataFrame([pd.DataFrame(d[c]['time_list'])['run_time'] for c in d]).T
runtime.columns = d.columns
runtime
# Out:
#     test_chrome_gmail_ail_reply_mail  test_firefox_gmail_ail_reply_mail
# 0                         122.222222                         266.666667
# 1                         122.222222                         255.555556
# 2                         100.000000                         233.333333
# 3                         122.222222                         244.444444
# 4                         122.222222                         233.333333
# 5                         122.222222                         244.444444
# 6                         122.222222                         444.444444
# 7                         111.111111                         255.555556
# 8                         144.444444                         255.555556
# 9                         111.111111                         211.111111
# 10                        111.111111                         244.444444
# 11                        111.111111                         233.333333
# 12                        111.111111                         255.555556
# 13                        155.555556                         244.444444
# 14                        122.222222                         233.333333
# 15                        111.111111                         244.444444
# 16                        122.222222                         244.444444
# 17                        122.222222                         266.666667
# 18                        122.222222                         300.000000
# 19                        111.111111                         244.444444
# 20                        133.333333                         266.666667
# 21                        133.333333                         244.444444
# 22                        155.555556                         277.777778
# 23                        122.222222                         255.555556
# 24                        122.222222                         255.555556
# 25                        111.111111                         233.333333
# 26                        122.222222                         266.666667
# 27                        111.111111                         211.111111
# 28                        133.333333                         211.111111
# 29                        111.111111                         233.333333

# %%
# Report percentile
runtime.quantile([0.01, 0.95, 0.99], interpolation='nearest')
# Out:
#       test_chrome_gmail_ail_reply_mail  test_firefox_gmail_ail_reply_mail
# 0.01                        100.000000                         211.111111
# 0.95                        155.555556                         300.000000
# 0.99                        155.555556                         444.444444

# %%
# Report summary
runtime.describe()
# Out:
#        test_chrome_gmail_ail_reply_mail  test_firefox_gmail_ail_reply_mail
# count                         30.000000                          30.000000
# mean                         121.851852                         253.703704
# std                           12.879681                          40.859574
# min                          100.000000                         211.111111
# 25%                          111.111111                         233.333333
# 50%                          122.222222                         244.444444
# 75%                          122.222222                         255.555556
# max                          155.555556                         444.444444

# %%
# Plot input latency histogram
runtime.plot.hist(bins=20, 
                  histtype='bar',
                  color=color_list,
                  subplots=True, layout=(1,fig_no),
                  figsize=(fig_size,10))
runtime.plot.box(subplots=True,
                 layout=(1,fig_no),
                 sharey=True, sharex=True, figsize=(fig_size, 10))
plt.show()
plt.show()
